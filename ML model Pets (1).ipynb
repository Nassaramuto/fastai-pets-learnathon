# %% [markdown]
# ![](https://github.com/muellerzr/Practical-Deep-Learning-for-Coders-2.0/blob/master/walkwithfastai.png?raw=true)
#
# ## About this course/study group:
# * It's a hybrid
# * Like Practical Deep Learning for Coders but many bonuses
# * Spans 2-3 hours depending on who stays with 1-1.5 hour lectures
#
# ## About Me:
# * Been doing fastai for 1.5 years
# * A few projects (some involving fastai, some not)
# * University undergraduate, Software Design and Development with a minor in ES
#
# ## Why did I make this?
# * Make fastai accessable to Undergraduates at my school (University of West Florida)
# * We both learn
# * Techniques not mentioned in the course

# %% [markdown]
# # Course Schedule
#
# **BLOCKS**:
# * Block 1: Computer Vision
# * Block 2: Tabular Neural Networks
# * Block 3: Natural Language Processing
#
# **Block 1** (January 15th - February 26th):
# * **Lesson 1: PETs and Custom Datasets (a warm introduction to the DataBlock API)**
# * Lesson 2: Image Classification Models from Scratch, Stochastic Gradient Descent
# * Lesson 3: Multi-Label Classification, and Dealing with Unknown Labels
# * Lesson 4: Image Segmentation, State-of-the-Art in Computer Vision
# * Lesson 5: Style Transfer, `nbdev`, and Deployment
# * Lesson 6: Keypoint Regression and Pose Detection
# * Lesson 7: Image Generation and Object Detection
# * Lesson 8: Audio
#
# **Block 2** (March 4th - March 25th):
# * Lesson 1: Pandas Workshop and Tabular Classification
# * Lesson 2: Feature Engineering and Tabular Regression
# * Lesson 3: Permutation Importance, Bayesian Optimization, Cross-Validation, and Labeled Test Sets
# * Lesson 4: NODE, TabNet, DeepGBM
#
# **BLOCK 3** (April 1st - April 22nd):
# * Lesson 1: Introduction to NLP and the LSTM
# * Lesson 2: Full Sentiment Classification, Tokenizers, and Ensembling
# * Lesson 3: Other State-of-the-Art NLP Models
# * Lesson 4: Multi-Lingual Data, DeViSe
#
# Looks very intense, if you don't keep up it's okay. Lectures are recorded.

# %% [markdown]
# # Requirements:
#
# * A Google account to use Google Colaboratory (what I am in right now)
# * A Paperspace account for Natural Language Processing

# %% [markdown]
# # Communication
# * Key to making study groups work!
# * We have a dedicated mega-thread on the fastai forums [here](https://forums.fast.ai/t/a-walk-with-fastai-study-group-and-online-lectures-megathread/59929) for us to use!
# * No question is too stupid!

# %% [markdown]
# # Enough intro, can I learn already?

# %% [markdown]
# # Environment setup
#
# Google Colaboratory - Free GPU's
#
# Go to [here](colab.research.google.com) to start using it.

# %% [markdown]
# File -> Open notebook

# %% [markdown]
# ![](https://i.imgur.com/pGCkS9G.png)

# %% [markdown]
# Select from GitHub and use the following URL: muellerzr/A-walk-with-fastai

# %% [markdown]
# ![](https://i.imgur.com/9O1LMZt.png)

# %% [markdown]
# Choose open in a new tab

# %% [markdown]
# ![](https://i.imgur.com/NuL67k9.png)

# %% [markdown]
# And now your screen looks similar to below! (With what I am using instead)

# %% [markdown]
# ![alt text](https://i.imgur.com/n4mQ2qj.png)

# %% [markdown]
# ## Changing our processer to a GPU

# %% [markdown]
# * 'Runtime'
# * 'Change runtime type'
# * 'Runtime type' should be 'Python 3'
# * 'Hardware accelerator' should be 'GPU'

# %% [markdown]
# ## Initial Run Warning (For pulling from GitHub)

# %% [markdown]
# ***If you get a pop up saying 'Warning: This notebook was not authored by Google,' check 'Reset all runtimes before running' and click 'Run Anyway'***

# %% [markdown]
# ![alt text](https://course.fast.ai/images/colab/02.png)

# %% [markdown]
# ## Saving your work
#
# For now this will just save the notebook on their cloud, we will look next week how to utilize your Google Drives!

# %% [markdown]
# ![alt text](https://course.fast.ai/images/colab/09.png)

# %% [markdown]
# # What is fastai?
#
# * Neural-network based library
# * Helps make state-of-the-art more accessible
# * Supports five datatypes:
#   * Computer vision (fastai.vision)
#   * Tabular data (fastai.tabular)
#   * Text (fastai.text)
#   * Collaborative filtering (fastai.collab) - **not going over**

# %% [markdown]
# # What is our goal today?
#
# * Make an image classifier for Cats and Dogs
# * Make our own image classifier
# * Start to understand the DataBlock API

# %% [markdown]
# # Let's grab the library:

# %%
#Run once per session
# !pip install fastai -q --upgrade

# %% [markdown]
# Now we can import the `fastai` libraries (fastai 2.0!)
#
# Today we will be using the `basics`, `callback`, and `vision` libraries as we have a **vision** task

# %%
from fastai.basics import *
from fastai.vision.all import *
from fastai.callback.all import *

# %% [markdown]
# Overall process using machine learning models and fastai:
# 1. Make our `DataLoaders`
# 2. Make a `Learner` with some "equipment"
# 3. Train

# %% [markdown]
# ## Looking at Data

# %% [markdown]
# We'll be trying to identify between 12 species of cats and 25 species of dogs (37 in total). Five years ago, the best was 59% with seperate classifications for the image, head, and body of the animal. Let's try just doing one image for everything.
#
# But before anything, we need data!

# %%
help(untar_data)
# Out:
# Help on function untar_data in module fastai.data.external:
#
# untar_data(url: 'str', archive: 'Path' = None, data: 'Path' = None, c_key: 'str' = 'data', force_download: 'bool' = False, base: 'str' = None) -> 'Path'
#     Download `url` using `FastDownload.get`

# %%
untar_data??
# Out:
# Signature:
# untar_data(
#     url: 'str',
#     archive: 'Path' = None,
#     data: 'Path' = None,
#     c_key: 'str' = 'data',
#     force_download: 'bool' = False,
#     base: 'str' = None,
# ) -> 'Path'
# Source:
# def untar_data(
#     url:str, # File to download
#     archive:Path=None, # Optional override for `Config`'s `archive` key
#     data:Path=None, # Optional override for `Config`'s `data` key
#     c_key:str='data', # Key in `Config` where to extract file
#     force_download:bool=False, # Setting to `True` will overwrite any existing copy of data
#     base:str=None # Directory containing config file and base of relative paths
# ) -> Path: # Path to extracted file(s)
#     "Download `url` using `FastDownload.get`"
#     cfg = None
#     if base is None:
#         cfg = fastai_cfg()
#         # A base must be provided as FastDownload initializes a Path with it even
#         # though the config provided is ultimately used instead.
#         base = '~/.fastai'
#     d = FastDownload(cfg, module=fastai.data, archive=archive, data=data, base=base)
#     return d.get(url, force=force_download, extract_key=c_key)
# File:      ~/Library/Python/3.9/lib/python/site-packages/fastai/data/external.py
# Type:      function

# %% [markdown]
# Let's download the dataset

# %%
path = untar_data(URLs.PETS)

# %% [markdown]
# And set our seed

# %%
np.random.seed(2)

# %% [markdown]
# How will our data look?

# %%
path.ls()[:3]
# Out:
# (#2) [Path('/Users/Stephane/.fastai/data/oxford-iiit-pet/images'),Path('/Users/Stephane/.fastai/data/oxford-iiit-pet/annotations')]

# %% [markdown]
# Let's build a `DataLoaders`.

# %%
path = untar_data(URLs.PETS)
fnames = get_image_files(path/'images')
pat = r'(.+)_\d+.jpg$'

# %% [markdown]
# Some  basic transforms

# %%
batch_tfms = [*aug_transforms(size=224, max_warp=0), Normalize.from_stats(*imagenet_stats)]
item_tfms = RandomResizedCrop(460, min_scale=0.75, ratio=(1.,1.))
bs=64

# %% [markdown]
# `ImageDataBunch` (renamed to ImageDataLoaders) - highest level API

# %%
dls = ImageDataLoaders.from_name_re(path, fnames, pat, batch_tfms=batch_tfms, 
                                   item_tfms=item_tfms, bs=bs)
# Out:
# Could not do one pass in your dataloader, there is something wrong in it. Please see the stack trace below:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 dls = ImageDataLoaders.from_name_re(path, fnames, pat, batch_tfms=batch_tfms,
#       2                                    item_tfms=item_tfms, bs=bs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/vision/data.py:162, in ImageDataLoaders.from_name_re(cls, path, fnames, pat, **kwargs)
#     158 @classmethod
#     159 @delegates(DataLoaders.from_dblock)
#     160 def from_name_re(cls, path, fnames, pat, **kwargs):
#     161     "Create from the name attrs of `fnames` in `path`s with re expression `pat`"
# --> 162     return cls.from_name_func(path, fnames, RegexLabeller(pat), **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/vision/data.py:151, in ImageDataLoaders.from_name_func(cls, path, fnames, label_func, **kwargs)
#     149     raise ValueError("label_func couldn't be lambda function on Windows")
#     150 f = using_attr(label_func, 'name')
# --> 151 return cls.from_path_func(path, fnames, f, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/vision/data.py:137, in ImageDataLoaders.from_path_func(cls, path, fnames, label_func, valid_pct, seed, item_tfms, batch_tfms, img_cls, **kwargs)
#     131 "Create from list of `fnames` in `path`s with `label_func`"
#     132 dblock = DataBlock(blocks=(ImageBlock(img_cls), CategoryBlock),
#     133                    splitter=RandomSplitter(valid_pct, seed=seed),
#     134                    get_y=label_func,
#     135                    item_tfms=item_tfms,
#     136                    batch_tfms=batch_tfms)
# --> 137 return cls.from_dblock(dblock, fnames, path=path, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/data/core.py:275, in DataLoaders.from_dblock(cls, dblock, source, path, bs, val_bs, shuffle, device, **kwargs)
#     264 @classmethod
#     265 def from_dblock(cls,
#     266     dblock, # `DataBlock` object
#    (...)
#     273     **kwargs
#     274 ):
# --> 275     return dblock.dataloaders(source, path=path, bs=bs, val_bs=val_bs, shuffle=shuffle, device=device, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/data/block.py:159, in DataBlock.dataloaders(self, source, path, verbose, **kwargs)
#     157 dsets = self.datasets(source, verbose=verbose)
#     158 kwargs = {**self.dls_kwargs, **kwargs, 'verbose': verbose}
# --> 159 return dsets.dataloaders(path=path, after_item=self.item_tfms, after_batch=self.batch_tfms, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/data/core.py:328, in FilteredBase.dataloaders(self, bs, shuffle_train, shuffle, val_shuffle, n, path, dl_type, dl_kwargs, device, drop_last, val_bs, **kwargs)
#     326 dl = dl_type(self.subset(0), **merge(kwargs,def_kwargs, dl_kwargs[0]))
#     327 def_kwargs = {'bs':bs if val_bs is None else val_bs,'shuffle':val_shuffle,'n':None,'drop_last':False}
# --> 328 dls = [dl] + [dl.new(self.subset(i), **merge(kwargs,def_kwargs,val_kwargs,dl_kwargs[i]))
#     329               for i in range(1, self.n_subsets)]
#     330 return self._dbunch_type(*dls, path=path, device=device)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/data/core.py:328, in <listcomp>(.0)
#     326 dl = dl_type(self.subset(0), **merge(kwargs,def_kwargs, dl_kwargs[0]))
#     327 def_kwargs = {'bs':bs if val_bs is None else val_bs,'shuffle':val_shuffle,'n':None,'drop_last':False}
# --> 328 dls = [dl] + [dl.new(self.subset(i), **merge(kwargs,def_kwargs,val_kwargs,dl_kwargs[i]))
#     329               for i in range(1, self.n_subsets)]
#     330 return self._dbunch_type(*dls, path=path, device=device)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/data/core.py:99, in TfmdDL.new(self, dataset, cls, **kwargs)
#      97 if not hasattr(self, '_n_inp') or not hasattr(self, '_types'):
#      98     try:
# ---> 99         self._one_pass()
#     100         res._n_inp,res._types = self._n_inp,self._types
#     101     except Exception as e:
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/data/core.py:82, in TfmdDL._one_pass(self)
#      80 b = self.do_batch([self.do_item(None)])
#      81 if self.device is not None: b = to_device(b, self.device)
# ---> 82 its = self.after_batch(b)
#      83 self._n_inp = 1 if not isinstance(its, (list,tuple)) or len(its)==1 else len(its)-1
#      84 self._types = explode_types(its)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastcore/transform.py:210, in Pipeline.__call__(self, o)
# --> 210 def __call__(self, o): return compose_tfms(o, tfms=self.fs, split_idx=self.split_idx)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastcore/transform.py:160, in compose_tfms(x, tfms, is_enc, reverse, **kwargs)
#     158 for f in tfms:
#     159     if not is_enc: f = f.decode
# --> 160     x = f(x, **kwargs)
#     161 return x
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/vision/augment.py:51, in RandTransform.__call__(self, b, split_idx, **kwargs)
#      45 def __call__(self,
#      46     b,
#      47     split_idx:int=None, # Index of the train/valid dataset
#      48     **kwargs
#      49 ):
#      50     self.before_call(b, split_idx=split_idx)
# ---> 51     return super().__call__(b, split_idx=split_idx, **kwargs) if self.do else b
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastcore/transform.py:83, in Transform.__call__(self, x, **kwargs)
# ---> 83 def __call__(self, x, **kwargs): return self._call('encodes', x, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastcore/transform.py:93, in Transform._call(self, fn, x, split_idx, **kwargs)
#      91 def _call(self, fn, x, split_idx=None, **kwargs):
#      92     if split_idx!=self.split_idx and self.split_idx is not None: return x
# ---> 93     return self._do_call(getattr(self, fn), x, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastcore/transform.py:100, in Transform._do_call(self, f, x, **kwargs)
#      98     ret = f.returns(x) if hasattr(f,'returns') else None
#      99     return retain_type(f(x, **kwargs), x, ret)
# --> 100 res = tuple(self._do_call(f, x_, **kwargs) for x_ in x)
#     101 return retain_type(res, x)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastcore/transform.py:100, in <genexpr>(.0)
#      98     ret = f.returns(x) if hasattr(f,'returns') else None
#      99     return retain_type(f(x, **kwargs), x, ret)
# --> 100 res = tuple(self._do_call(f, x_, **kwargs) for x_ in x)
#     101 return retain_type(res, x)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastcore/transform.py:99, in Transform._do_call(self, f, x, **kwargs)
#      97     if f is None: return x
#      98     ret = f.returns(x) if hasattr(f,'returns') else None
# ---> 99     return retain_type(f(x, **kwargs), x, ret)
#     100 res = tuple(self._do_call(f, x_, **kwargs) for x_ in x)
#     101 return retain_type(res, x)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastcore/dispatch.py:122, in TypeDispatch.__call__(self, *args, **kwargs)
#     120 elif self.inst is not None: f = MethodType(f, self.inst)
#     121 elif self.owner is not None: f = MethodType(f, self.owner)
# --> 122 return f(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/vision/augment.py:503, in AffineCoordTfm.encodes(self, x)
# --> 503 def encodes(self, x:TensorImage): return self._encode(x, self.mode)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/vision/augment.py:501, in AffineCoordTfm._encode(self, x, mode, reverse)
#     499 def _encode(self, x, mode, reverse=False):
#     500     coord_func = None if len(self.coord_fs)==0 or self.split_idx else partial(compose_tfms, tfms=self.coord_fs, reverse=reverse)
# --> 501     return x.affine_coord(self.mat, coord_func, sz=self.size, mode=mode, pad_mode=self.pad_mode, align_corners=self.align_corners)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/vision/augment.py:393, in affine_coord(x, mat, coord_tfm, sz, mode, pad_mode, align_corners)
#     391 coords = affine_grid(mat, x.shape[:2] + size, align_corners=align_corners)
#     392 if coord_tfm is not None: coords = coord_tfm(coords)
# --> 393 return TensorImage(_grid_sample(x, coords, mode=mode, padding_mode=pad_mode, align_corners=align_corners))
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/vision/augment.py:365, in _grid_sample(x, coords, mode, padding_mode, align_corners)
#     363     # If we're resizing up by >200%, and we're zooming less than that, interpolate first
#     364     if d>1 and d>z:
# --> 365         x = F.interpolate(x, scale_factor=1/d, mode='area', recompute_scale_factor=True)
#     366 return F.grid_sample(x, coords, mode=mode, padding_mode=padding_mode, align_corners=align_corners)
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/functional.py:4531, in interpolate(input, size, scale_factor, mode, align_corners, recompute_scale_factor, antialias)
#    4462 r"""Down/up samples the input.
#    4463
#    4464 Tensor interpolated to either the given :attr:`size` or the given
#    (...)
#    4528     {backward_reproducibility_note}
#    4529 """
#    4530 if has_torch_function_unary(input):
# -> 4531     return handle_torch_function(
#    4532         interpolate,
#    4533         (input,),
#    4534         input,
#    4535         size=size,
#    4536         scale_factor=scale_factor,
#    4537         mode=mode,
#    4538         align_corners=align_corners,
#    4539         recompute_scale_factor=recompute_scale_factor,
#    4540         antialias=antialias,
#    4541     )
#    4543 if mode in ("nearest", "area", "nearest-exact"):
#    4544     if align_corners is not None:
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/overrides.py:1742, in handle_torch_function(public_api, relevant_args, *args, **kwargs)
#    1734     warnings.warn(
#    1735         "Defining your `__torch_function__ as a plain method is deprecated and "
#    1736         "will be an error in future, please define it as a classmethod.",
#    1737         DeprecationWarning,
#    1738     )
#    1740 # Use `public_api` instead of `implementation` so __torch_function__
#    1741 # implementations can do equality/identity comparisons.
# -> 1742 result = torch_func_method(public_api, types, args, kwargs)
#    1744 if result is not NotImplemented:
#    1745     return result
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/torch_core.py:384, in TensorBase.__torch_function__(cls, func, types, args, kwargs)
#     382 if cls.debug and func.__name__ not in ('__str__','__repr__'): print(func, types, args, kwargs)
#     383 if _torch_handled(args, cls._opt, func): types = (torch.Tensor,)
# --> 384 res = super().__torch_function__(func, types, args, ifnone(kwargs, {}))
#     385 dict_objs = _find_args(args) if args else _find_args(list(kwargs.values()))
#     386 if issubclass(type(res),TensorBase) and dict_objs: res.set_meta(dict_objs[0],as_copy=True)
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/_tensor.py:1648, in Tensor.__torch_function__(cls, func, types, args, kwargs)
#    1645     return NotImplemented
#    1647 with _C.DisableTorchFunctionSubclass():
# -> 1648     ret = func(*args, **kwargs)
#    1649     if func in get_default_nowrap_functions():
#    1650         return ret
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/functional.py:4665, in interpolate(input, size, scale_factor, mode, align_corners, recompute_scale_factor, antialias)
#    4663 if input.dim() == 4 and mode == "area":
#    4664     assert output_size is not None
# -> 4665     return adaptive_avg_pool2d(input, output_size)
#    4666 if input.dim() == 5 and mode == "area":
#    4667     assert output_size is not None
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/functional.py:1382, in adaptive_avg_pool2d(input, output_size)
#    1380     return handle_torch_function(adaptive_avg_pool2d, (input,), input, output_size)
#    1381 _output_size = _list_with_default(output_size, input.size())
# -> 1382 return torch._C._nn.adaptive_avg_pool2d(input, _output_size)
#
# RuntimeError: Adaptive pool MPS: input sizes must be divisible by output sizes. Non-divisible input sizes are not implemented on MPS device yet. For now, you can manually transfer tensor to cpu in this case. Please refer to [this issue](https://github.com/pytorch/pytorch/issues/96056)

# %% [markdown]
# What is the API?
#
# * See PPT

# %% [markdown]
# Let's rebuild using the `DataBlock` api - Medium Level

# %%
pets = DataBlock(blocks=(ImageBlock, CategoryBlock),
                 get_items=get_image_files,
                 splitter=RandomSplitter(),
                 get_y=RegexLabeller(pat = r'/([^/]+)_\d+.*'),
                 item_tfms=item_tfms,
                 batch_tfms=batch_tfms)

# %%
path_im = path/'images'

# %%
dls = pets.dataloaders(path_im, bs=bs)
# Out:
# Could not do one pass in your dataloader, there is something wrong in it. Please see the stack trace below:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 dls = pets.dataloaders(path_im, bs=bs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/data/block.py:159, in DataBlock.dataloaders(self, source, path, verbose, **kwargs)
#     157 dsets = self.datasets(source, verbose=verbose)
#     158 kwargs = {**self.dls_kwargs, **kwargs, 'verbose': verbose}
# --> 159 return dsets.dataloaders(path=path, after_item=self.item_tfms, after_batch=self.batch_tfms, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/data/core.py:328, in FilteredBase.dataloaders(self, bs, shuffle_train, shuffle, val_shuffle, n, path, dl_type, dl_kwargs, device, drop_last, val_bs, **kwargs)
#     326 dl = dl_type(self.subset(0), **merge(kwargs,def_kwargs, dl_kwargs[0]))
#     327 def_kwargs = {'bs':bs if val_bs is None else val_bs,'shuffle':val_shuffle,'n':None,'drop_last':False}
# --> 328 dls = [dl] + [dl.new(self.subset(i), **merge(kwargs,def_kwargs,val_kwargs,dl_kwargs[i]))
#     329               for i in range(1, self.n_subsets)]
#     330 return self._dbunch_type(*dls, path=path, device=device)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/data/core.py:328, in <listcomp>(.0)
#     326 dl = dl_type(self.subset(0), **merge(kwargs,def_kwargs, dl_kwargs[0]))
#     327 def_kwargs = {'bs':bs if val_bs is None else val_bs,'shuffle':val_shuffle,'n':None,'drop_last':False}
# --> 328 dls = [dl] + [dl.new(self.subset(i), **merge(kwargs,def_kwargs,val_kwargs,dl_kwargs[i]))
#     329               for i in range(1, self.n_subsets)]
#     330 return self._dbunch_type(*dls, path=path, device=device)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/data/core.py:99, in TfmdDL.new(self, dataset, cls, **kwargs)
#      97 if not hasattr(self, '_n_inp') or not hasattr(self, '_types'):
#      98     try:
# ---> 99         self._one_pass()
#     100         res._n_inp,res._types = self._n_inp,self._types
#     101     except Exception as e:
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/data/core.py:82, in TfmdDL._one_pass(self)
#      80 b = self.do_batch([self.do_item(None)])
#      81 if self.device is not None: b = to_device(b, self.device)
# ---> 82 its = self.after_batch(b)
#      83 self._n_inp = 1 if not isinstance(its, (list,tuple)) or len(its)==1 else len(its)-1
#      84 self._types = explode_types(its)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastcore/transform.py:210, in Pipeline.__call__(self, o)
# --> 210 def __call__(self, o): return compose_tfms(o, tfms=self.fs, split_idx=self.split_idx)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastcore/transform.py:160, in compose_tfms(x, tfms, is_enc, reverse, **kwargs)
#     158 for f in tfms:
#     159     if not is_enc: f = f.decode
# --> 160     x = f(x, **kwargs)
#     161 return x
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/vision/augment.py:51, in RandTransform.__call__(self, b, split_idx, **kwargs)
#      45 def __call__(self,
#      46     b,
#      47     split_idx:int=None, # Index of the train/valid dataset
#      48     **kwargs
#      49 ):
#      50     self.before_call(b, split_idx=split_idx)
# ---> 51     return super().__call__(b, split_idx=split_idx, **kwargs) if self.do else b
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastcore/transform.py:83, in Transform.__call__(self, x, **kwargs)
# ---> 83 def __call__(self, x, **kwargs): return self._call('encodes', x, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastcore/transform.py:93, in Transform._call(self, fn, x, split_idx, **kwargs)
#      91 def _call(self, fn, x, split_idx=None, **kwargs):
#      92     if split_idx!=self.split_idx and self.split_idx is not None: return x
# ---> 93     return self._do_call(getattr(self, fn), x, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastcore/transform.py:100, in Transform._do_call(self, f, x, **kwargs)
#      98     ret = f.returns(x) if hasattr(f,'returns') else None
#      99     return retain_type(f(x, **kwargs), x, ret)
# --> 100 res = tuple(self._do_call(f, x_, **kwargs) for x_ in x)
#     101 return retain_type(res, x)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastcore/transform.py:100, in <genexpr>(.0)
#      98     ret = f.returns(x) if hasattr(f,'returns') else None
#      99     return retain_type(f(x, **kwargs), x, ret)
# --> 100 res = tuple(self._do_call(f, x_, **kwargs) for x_ in x)
#     101 return retain_type(res, x)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastcore/transform.py:99, in Transform._do_call(self, f, x, **kwargs)
#      97     if f is None: return x
#      98     ret = f.returns(x) if hasattr(f,'returns') else None
# ---> 99     return retain_type(f(x, **kwargs), x, ret)
#     100 res = tuple(self._do_call(f, x_, **kwargs) for x_ in x)
#     101 return retain_type(res, x)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastcore/dispatch.py:122, in TypeDispatch.__call__(self, *args, **kwargs)
#     120 elif self.inst is not None: f = MethodType(f, self.inst)
#     121 elif self.owner is not None: f = MethodType(f, self.owner)
# --> 122 return f(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/vision/augment.py:503, in AffineCoordTfm.encodes(self, x)
# --> 503 def encodes(self, x:TensorImage): return self._encode(x, self.mode)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/vision/augment.py:501, in AffineCoordTfm._encode(self, x, mode, reverse)
#     499 def _encode(self, x, mode, reverse=False):
#     500     coord_func = None if len(self.coord_fs)==0 or self.split_idx else partial(compose_tfms, tfms=self.coord_fs, reverse=reverse)
# --> 501     return x.affine_coord(self.mat, coord_func, sz=self.size, mode=mode, pad_mode=self.pad_mode, align_corners=self.align_corners)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/vision/augment.py:393, in affine_coord(x, mat, coord_tfm, sz, mode, pad_mode, align_corners)
#     391 coords = affine_grid(mat, x.shape[:2] + size, align_corners=align_corners)
#     392 if coord_tfm is not None: coords = coord_tfm(coords)
# --> 393 return TensorImage(_grid_sample(x, coords, mode=mode, padding_mode=pad_mode, align_corners=align_corners))
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/vision/augment.py:365, in _grid_sample(x, coords, mode, padding_mode, align_corners)
#     363     # If we're resizing up by >200%, and we're zooming less than that, interpolate first
#     364     if d>1 and d>z:
# --> 365         x = F.interpolate(x, scale_factor=1/d, mode='area', recompute_scale_factor=True)
#     366 return F.grid_sample(x, coords, mode=mode, padding_mode=padding_mode, align_corners=align_corners)
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/functional.py:4531, in interpolate(input, size, scale_factor, mode, align_corners, recompute_scale_factor, antialias)
#    4462 r"""Down/up samples the input.
#    4463
#    4464 Tensor interpolated to either the given :attr:`size` or the given
#    (...)
#    4528     {backward_reproducibility_note}
#    4529 """
#    4530 if has_torch_function_unary(input):
# -> 4531     return handle_torch_function(
#    4532         interpolate,
#    4533         (input,),
#    4534         input,
#    4535         size=size,
#    4536         scale_factor=scale_factor,
#    4537         mode=mode,
#    4538         align_corners=align_corners,
#    4539         recompute_scale_factor=recompute_scale_factor,
#    4540         antialias=antialias,
#    4541     )
#    4543 if mode in ("nearest", "area", "nearest-exact"):
#    4544     if align_corners is not None:
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/overrides.py:1742, in handle_torch_function(public_api, relevant_args, *args, **kwargs)
#    1734     warnings.warn(
#    1735         "Defining your `__torch_function__ as a plain method is deprecated and "
#    1736         "will be an error in future, please define it as a classmethod.",
#    1737         DeprecationWarning,
#    1738     )
#    1740 # Use `public_api` instead of `implementation` so __torch_function__
#    1741 # implementations can do equality/identity comparisons.
# -> 1742 result = torch_func_method(public_api, types, args, kwargs)
#    1744 if result is not NotImplemented:
#    1745     return result
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/torch_core.py:384, in TensorBase.__torch_function__(cls, func, types, args, kwargs)
#     382 if cls.debug and func.__name__ not in ('__str__','__repr__'): print(func, types, args, kwargs)
#     383 if _torch_handled(args, cls._opt, func): types = (torch.Tensor,)
# --> 384 res = super().__torch_function__(func, types, args, ifnone(kwargs, {}))
#     385 dict_objs = _find_args(args) if args else _find_args(list(kwargs.values()))
#     386 if issubclass(type(res),TensorBase) and dict_objs: res.set_meta(dict_objs[0],as_copy=True)
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/_tensor.py:1648, in Tensor.__torch_function__(cls, func, types, args, kwargs)
#    1645     return NotImplemented
#    1647 with _C.DisableTorchFunctionSubclass():
# -> 1648     ret = func(*args, **kwargs)
#    1649     if func in get_default_nowrap_functions():
#    1650         return ret
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/functional.py:4665, in interpolate(input, size, scale_factor, mode, align_corners, recompute_scale_factor, antialias)
#    4663 if input.dim() == 4 and mode == "area":
#    4664     assert output_size is not None
# -> 4665     return adaptive_avg_pool2d(input, output_size)
#    4666 if input.dim() == 5 and mode == "area":
#    4667     assert output_size is not None
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/functional.py:1382, in adaptive_avg_pool2d(input, output_size)
#    1380     return handle_torch_function(adaptive_avg_pool2d, (input,), input, output_size)
#    1381 _output_size = _list_with_default(output_size, input.size())
# -> 1382 return torch._C._nn.adaptive_avg_pool2d(input, _output_size)
#
# RuntimeError: Adaptive pool MPS: input sizes must be divisible by output sizes. Non-divisible input sizes are not implemented on MPS device yet. For now, you can manually transfer tensor to cpu in this case. Please refer to [this issue](https://github.com/pytorch/pytorch/issues/96056)

# %% [markdown]
# We can take a look at a batch of our images using `show_batch` and pass in a aximum number of images to show, and how large we want to view them as

# %%
dls.show_batch(max_n=9, figsize=(6,7))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 dls.show_batch(max_n=9, figsize=(6,7))
#
# NameError: name 'dls' is not defined

# %% [markdown]
# If we want to see how many classes we have, and the names of them we can simply call `dls.vocab`. The first is the number of classes, the second is the names of our classes. You may notice this looks a bit odd, that's because this `L` is a new invention of Jeremy and Sylvian. Essentially it's a Python list taken to the extreme.
#
# Before if we wanted to grab the index for the name of a class (eg. our model output 0 as our class), we would need to use `data.c2i` to grab the Class2Index mapping. This is still here, it lives in `dls.vocab.o2i`

# %%
dls.vocab
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 dls.vocab
#
# NameError: name 'dls' is not defined

# %%
dls.vocab.o2i
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 dls.vocab.o2i
#
# NameError: name 'dls' is not defined

# %% [markdown]
# ## Time to make and train a model!

# %% [markdown]
# We will be using a convolutional neural network backbone and a fully connected head with a single hidden layer as our classifier. Don't worry if thats a bunch of nonsense for now. Right now, just know this: we are piggybacking off of a model to help us classify images into 37 categories.

# %% [markdown]
# First, we need to make our Neural Network and our `Learner` like before.
#
# A `Learner` needs (on a base level):
#
# * `DataLoaders`
# * Some architecture
# * A evaluation metric
# * A loss function
# * An optimizer
#
# We'll also use `mixed_precision` (`fp16`)

# %%
learn = cnn_learner(dls, resnet34, pretrained=True, metrics=error_rate).to_fp16()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 learn = cnn_learner(dls, resnet34, pretrained=True, metrics=error_rate).to_fp16()
#
# NameError: name 'dls' is not defined

# %% [markdown]
# Some assumptions being made here:
#
# * Loss function is assumed as classification, so `CrossEntropyFlat`
# * Optimizer is assumed to be Adam

# %% [markdown]
# Now, we can train it! We will train it for four cycles through all our data

# %%
learn.fit_one_cycle(4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 learn.fit_one_cycle(4)
#
# NameError: name 'learn' is not defined

# %%
learn.save('stage_1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 learn.save('stage_1')
#
# NameError: name 'learn' is not defined

# %% [markdown]
# ## Lets look at our results

# %% [markdown]
# With the model trained, let's look at where our it might've messed up. What species did it have trouble differentiating between? So long as the misidentifications are not too crazy, our model is actually working.

# %% [markdown]
# Let's plot our losses and make a confusion matrix to visualize this. Below checks to make sure that all pieces we need are available

# %%
interp = ClassificationInterpretation.from_learner(learn)
losses,idxs = interp.top_losses()

len(dls.valid_ds)==len(losses)==len(idxs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 interp = ClassificationInterpretation.from_learner(learn)
#       2 losses,idxs = interp.top_losses()
#       4 len(dls.valid_ds)==len(losses)==len(idxs)
#
# NameError: name 'learn' is not defined

# %% [markdown]
# `plot_top_losses` needs `x` number of images to use, and a figure size.

# %%
interp.plot_top_losses(9, figsize=(15,10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 interp.plot_top_losses(9, figsize=(15,10))
#
# NameError: name 'interp' is not defined

# %% [markdown]
# `plot_confusion_matrix` just needs a figure size. dpi adjusts the quality

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 interp.plot_confusion_matrix(figsize=(12,12), dpi=60)
#
# NameError: name 'interp' is not defined

# %% [markdown]
# We can also directly grab our most confused (A raw version of the confusion matrix), and pass in a threshold

# %%
interp.most_confused(min_val=3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 interp.most_confused(min_val=3)
#
# NameError: name 'interp' is not defined

# %% [markdown]
# ## Unfreezing our data, fine-tuning, and our learning rates

# %% [markdown]
# So, we have the model. Let's fine tune it. First, we need to load our model back in.

# %%
learn.load('stage_1');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 learn.load('stage_1');
#
# NameError: name 'learn' is not defined

# %% [markdown]
# Now we will *unfreeze* and train more

# %%
learn.unfreeze()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 learn.unfreeze()
#
# NameError: name 'learn' is not defined

# %%
learn.fit_one_cycle(4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 learn.fit_one_cycle(4)
#
# NameError: name 'learn' is not defined

# %% [markdown]
# Now when we `unfreeze`, we unfreeze *all* the layers. So to show how a difference of a proper learning rate looks, let's load in those old weights and try using `lr_find()`

# %%
learn.load('stage_1');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 learn.load('stage_1');
#
# NameError: name 'learn' is not defined

# %%
learn.lr_find()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 learn.lr_find()
#
# NameError: name 'learn' is not defined

# %% [markdown]
# Alright so if we look here, we don't start really spiking our losses until ~10^-2 so a good spot is between 1e-6 and 1e-4, let's do that!

# %%
learn.unfreeze()
learn.fit_one_cycle(4, lr_max=slice(1e-6, 1e-4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 learn.unfreeze()
#       2 learn.fit_one_cycle(4, lr_max=slice(1e-6, 1e-4))
#
# NameError: name 'learn' is not defined

# %% [markdown]
# We can see that picking a proper learning rate can help speed things up!

# %%
learn.save('stage_2')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 learn.save('stage_2')
#
# NameError: name 'learn' is not defined

# %% [markdown]
# ## Now lets try with a resnet50!
#
# If you need to restart your kernel due to memory errors I've attached the `dls` code below

# %%
pets = DataBlock(blocks=(ImageBlock, CategoryBlock),
                 get_items=get_image_files,
                 splitter=RandomSplitter(),
                 get_y=RegexLabeller(pat = r'/([^/]+)_\d+.*'),
                 item_tfms=item_tfms,
                 batch_tfms=batch_tfms)

dls = pets.dataloaders(untar_data(URLs.PETS)/"images", bs=32)

# %% [markdown]
# Go ahead and try running the below code yourself. You *should* see a higher increase in accuracy!
#
# Steps to try:
#
# 1. Create your Learner
# 2. Find a learning rate
# 3. Fit for 5 epochs
# 4. Unfreeze and fit for two more

# %%
### Try here! ###

# %% [markdown]
# ## The answer is hidden under here

# %%
learn = cnn_learner(data, resnet50, pretrained=True, metrics=error_rate)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 learn = cnn_learner(data, resnet50, pretrained=True, metrics=error_rate)
#
# NameError: name 'data' is not defined

# %%
learn.lr_find()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 learn.lr_find()
#
# NameError: name 'learn' is not defined

# %%
learn.fit_one_cycle(5, lr_max=slice(3e-4, 3e-3))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 learn.fit_one_cycle(5, lr_max=slice(3e-4, 3e-3))
#
# NameError: name 'learn' is not defined

# %%
learn.save('resnet50')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 learn.save('resnet50')
#
# NameError: name 'learn' is not defined

# %%
learn.load('resnet50')
learn.unfreeze()
learn.fit_one_cycle(2, max_lr=4e-4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 learn.load('resnet50')
#       2 learn.unfreeze()
#       3 learn.fit_one_cycle(2, max_lr=4e-4)
#
# NameError: name 'learn' is not defined

# %%
learn.save('resnet50')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 learn.save('resnet50')
#
# NameError: name 'learn' is not defined

# %%
img = PILImage.create('dog.jpg')
img.show()
# Out:
# <Axes: >

# %%
learn.predict(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 learn.predict(img)
#
# NameError: name 'learn' is not defined

# %%
learn.model.cpu()  # Move model to CPU

# %%
pred_class, pred_idx, outputs = learn.predict(img)
print(f"Prediction: {pred_class}")

# %%
learn.model.cpu()  # Move model to CPU
defaults.device = torch.device('cpu')  # Ensure data gets moved to CPU too
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 learn.model.cpu()  # Move model to CPU
#       2 defaults.device = torch.device('cpu')  # Ensure data gets moved to CPU too
#
# NameError: name 'learn' is not defined

# %%
img = PILImage.create('dog.jpg')  # or whatever your file is called
img.show()
pred_class, pred_idx, outputs = learn.predict(img)
print(f"Prediction: {pred_class}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 3
#       1 img = PILImage.create('dog.jpg')  # or whatever your file is called
#       2 img.show()
# ----> 3 pred_class, pred_idx, outputs = learn.predict(img)
#       4 print(f"Prediction: {pred_class}")
#
# NameError: name 'learn' is not defined

# %%
import torch
torch.device("cpu")
defaults.device = torch.device("cpu")

# %%
learn = vision_learner(dls, resnet34, metrics=error_rate)
learn.model.cpu()

# %%
img = PILImage.create('dog.jpg')
img.show()

pred_class, pred_idx, outputs = learn.predict(img)
print(f"Prediction: {pred_class}")

# %%
import torch
from fastai.vision.all import *
torch.backends.mps.is_available()  # Optional: check if MPS is active
defaults.device = torch.device('cpu')

# %%
dls = ImageDataLoaders.from_name_re(
    path, get_image_files(path), pat=r'^(.*)_\d+.jpg$', item_tfms=Resize(224))

learn = vision_learner(dls, resnet34, metrics=error_rate)
learn.model.cpu()  # optional double assurance
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 dls = ImageDataLoaders.from_name_re(
#       2     path, get_image_files(path), pat=r'^(.*)_\d+.jpg$', item_tfms=Resize(224))
#       4 learn = vision_learner(dls, resnet34, metrics=error_rate)
#       5 learn.model.cpu()  # optional double assurance
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/vision/data.py:162, in ImageDataLoaders.from_name_re(cls, path, fnames, pat, **kwargs)
#     158 @classmethod
#     159 @delegates(DataLoaders.from_dblock)
#     160 def from_name_re(cls, path, fnames, pat, **kwargs):
#     161     "Create from the name attrs of `fnames` in `path`s with re expression `pat`"
# --> 162     return cls.from_name_func(path, fnames, RegexLabeller(pat), **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/vision/data.py:151, in ImageDataLoaders.from_name_func(cls, path, fnames, label_func, **kwargs)
#     149     raise ValueError("label_func couldn't be lambda function on Windows")
#     150 f = using_attr(label_func, 'name')
# --> 151 return cls.from_path_func(path, fnames, f, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/vision/data.py:137, in ImageDataLoaders.from_path_func(cls, path, fnames, label_func, valid_pct, seed, item_tfms, batch_tfms, img_cls, **kwargs)
#     131 "Create from list of `fnames` in `path`s with `label_func`"
#     132 dblock = DataBlock(blocks=(ImageBlock(img_cls), CategoryBlock),
#     133                    splitter=RandomSplitter(valid_pct, seed=seed),
#     134                    get_y=label_func,
#     135                    item_tfms=item_tfms,
#     136                    batch_tfms=batch_tfms)
# --> 137 return cls.from_dblock(dblock, fnames, path=path, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/data/core.py:275, in DataLoaders.from_dblock(cls, dblock, source, path, bs, val_bs, shuffle, device, **kwargs)
#     264 @classmethod
#     265 def from_dblock(cls,
#     266     dblock, # `DataBlock` object
#    (...)
#     273     **kwargs
#     274 ):
# --> 275     return dblock.dataloaders(source, path=path, bs=bs, val_bs=val_bs, shuffle=shuffle, device=device, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/data/block.py:157, in DataBlock.dataloaders(self, source, path, verbose, **kwargs)
#     151 def dataloaders(self,
#     152     source, # The data source
#     153     path:str='.', # Data source and default `Learner` path
#     154     verbose:bool=False, # Show verbose messages
#     155     **kwargs
#     156 ) -> DataLoaders:
# --> 157     dsets = self.datasets(source, verbose=verbose)
#     158     kwargs = {**self.dls_kwargs, **kwargs, 'verbose': verbose}
#     159     return dsets.dataloaders(path=path, after_item=self.item_tfms, after_batch=self.batch_tfms, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/data/block.py:149, in DataBlock.datasets(self, source, verbose)
#     147 splits = (self.splitter or RandomSplitter())(items)
#     148 pv(f"{len(splits)} datasets of sizes {','.join([str(len(s)) for s in splits])}", verbose)
# --> 149 return Datasets(items, tfms=self._combine_type_tfms(), splits=splits, dl_type=self.dl_type, n_inp=self.n_inp, verbose=verbose)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/data/core.py:445, in Datasets.__init__(self, items, tfms, tls, n_inp, dl_type, **kwargs)
#     436 def __init__(self,
#     437     items:list=None, # List of items to create `Datasets`
#     438     tfms:MutableSequence|Pipeline=None, # List of `Transform`(s) or `Pipeline` to apply
#    (...)
#     442     **kwargs
#     443 ):
#     444     super().__init__(dl_type=dl_type)
# --> 445     self.tls = L(tls if tls else [TfmdLists(items, t, **kwargs) for t in L(ifnone(tfms,[None]))])
#     446     self.n_inp = ifnone(n_inp, max(1, len(self.tls)-1))
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/data/core.py:445, in <listcomp>(.0)
#     436 def __init__(self,
#     437     items:list=None, # List of items to create `Datasets`
#     438     tfms:MutableSequence|Pipeline=None, # List of `Transform`(s) or `Pipeline` to apply
#    (...)
#     442     **kwargs
#     443 ):
#     444     super().__init__(dl_type=dl_type)
# --> 445     self.tls = L(tls if tls else [TfmdLists(items, t, **kwargs) for t in L(ifnone(tfms,[None]))])
#     446     self.n_inp = ifnone(n_inp, max(1, len(self.tls)-1))
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastcore/foundation.py:100, in _L_Meta.__call__(cls, x, *args, **kwargs)
#      98 def __call__(cls, x=None, *args, **kwargs):
#      99     if not args and not kwargs and x is not None and isinstance(x,cls): return x
# --> 100     return super().__call__(x, *args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/data/core.py:359, in TfmdLists.__init__(self, items, tfms, use_list, do_setup, split_idx, train_setup, splits, types, verbose, dl_type)
#     357 if do_setup:
#     358     pv(f"Setting up {self.tfms}", verbose)
# --> 359     self.setup(train_setup=train_setup)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/data/core.py:380, in TfmdLists.setup(self, train_setup)
#     377 def setup(self,
#     378     train_setup:bool=True # Apply `Transform`(s) only on training `DataLoader`
#     379 ):
# --> 380     self.tfms.setup(self, train_setup)
#     381     if len(self) != 0:
#     382         x = super().__getitem__(0) if self.splits is None else super().__getitem__(self.splits[0])[0]
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastcore/transform.py:202, in Pipeline.setup(self, items, train_setup)
#     200 tfms = self.fs[:]
#     201 self.fs.clear()
# --> 202 for t in tfms: self.add(t,items, train_setup)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastcore/transform.py:206, in Pipeline.add(self, ts, items, train_setup)
#     204 def add(self,ts, items=None, train_setup=False):
#     205     if not is_listy(ts): ts=[ts]
# --> 206     for t in ts: t.setup(items, train_setup)
#     207     self.fs+=ts
#     208     self.fs = self.fs.sorted(key='order')
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastcore/transform.py:89, in Transform.setup(self, items, train_setup)
#      87 def setup(self, items=None, train_setup=False):
#      88     train_setup = train_setup if self.train_setup is None else self.train_setup
# ---> 89     return self.setups(getattr(items, 'train', items) if train_setup else items)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastcore/dispatch.py:122, in TypeDispatch.__call__(self, *args, **kwargs)
#     120 elif self.inst is not None: f = MethodType(f, self.inst)
#     121 elif self.owner is not None: f = MethodType(f, self.owner)
# --> 122 return f(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/data/transforms.py:258, in Categorize.setups(self, dsets)
#     257 def setups(self, dsets):
# --> 258     if self.vocab is None and dsets is not None: self.vocab = CategoryMap(dsets, sort=self.sort, add_na=self.add_na)
#     259     self.c = len(self.vocab)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/data/transforms.py:234, in CategoryMap.__init__(self, col, sort, add_na, strict)
#     232     if not hasattr(col,'unique'): col = L(col, use_list=True)
#     233     # `o==o` is the generalized definition of non-NaN used by Pandas
# --> 234     items = L(o for o in col.unique() if o==o)
#     235     if sort: items = items.sorted()
#     236 self.items = '#na#' + items if add_na else items
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastcore/foundation.py:173, in L.unique(self, sort, bidir, start)
# --> 173 def unique(self, sort=False, bidir=False, start=None): return L(uniqueify(self, sort=sort, bidir=bidir, start=start))
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastcore/basics.py:808, in uniqueify(x, sort, bidir, start)
#     806 def uniqueify(x, sort=False, bidir=False, start=None):
#     807     "Unique elements in `x`, optional `sort`, optional return reverse correspondence, optional prepend with elements."
# --> 808     res = list(dict.fromkeys(x))
#     809     if start is not None: res = listify(start)+res
#     810     if sort: res.sort()
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/data/core.py:370, in <genexpr>(.0)
# --> 370 def __iter__(self): return (self[i] for i in range(len(self)))
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/data/core.py:408, in TfmdLists.__getitem__(self, idx)
#     406 res = super().__getitem__(idx)
#     407 if self._after_item is None: return res
# --> 408 return self._after_item(res) if is_indexer(idx) else res.map(self._after_item)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/data/core.py:368, in TfmdLists._after_item(self, o)
# --> 368 def _after_item(self, o): return self.tfms(o)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastcore/transform.py:210, in Pipeline.__call__(self, o)
# --> 210 def __call__(self, o): return compose_tfms(o, tfms=self.fs, split_idx=self.split_idx)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastcore/transform.py:160, in compose_tfms(x, tfms, is_enc, reverse, **kwargs)
#     158 for f in tfms:
#     159     if not is_enc: f = f.decode
# --> 160     x = f(x, **kwargs)
#     161 return x
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastcore/transform.py:83, in Transform.__call__(self, x, **kwargs)
# ---> 83 def __call__(self, x, **kwargs): return self._call('encodes', x, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastcore/transform.py:93, in Transform._call(self, fn, x, split_idx, **kwargs)
#      91 def _call(self, fn, x, split_idx=None, **kwargs):
#      92     if split_idx!=self.split_idx and self.split_idx is not None: return x
# ---> 93     return self._do_call(getattr(self, fn), x, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastcore/transform.py:99, in Transform._do_call(self, f, x, **kwargs)
#      97     if f is None: return x
#      98     ret = f.returns(x) if hasattr(f,'returns') else None
# ---> 99     return retain_type(f(x, **kwargs), x, ret)
#     100 res = tuple(self._do_call(f, x_, **kwargs) for x_ in x)
#     101 return retain_type(res, x)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastcore/dispatch.py:122, in TypeDispatch.__call__(self, *args, **kwargs)
#     120 elif self.inst is not None: f = MethodType(f, self.inst)
#     121 elif self.owner is not None: f = MethodType(f, self.owner)
# --> 122 return f(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastcore/basics.py:970, in _using_attr(f, attr, x)
# --> 970 def _using_attr(f, attr, x): return f(getattr(x,attr))
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/data/transforms.py:202, in RegexLabeller.__call__(self, o)
#     200 o = str(o).replace(os.sep, posixpath.sep)
#     201 res = self.matcher(o)
# --> 202 assert res,f'Failed to find "{self.pat}" in "{o}"'
#     203 return res.group(1)
#
# AssertionError: Failed to find "re.compile('^(.*)_\\d+.jpg$')" in "beagle_83.png"

# %%
img = PILImage.create('dog.jpg')
img.show()

pred_class, pred_idx, outputs = learn.predict(img)
print(f"Prediction: {pred_class}")

# %%
path = untar_data(URLs.PETS)/'images'

# %%
dls = ImageDataLoaders.from_name_re(
    path, get_image_files(path), pat=r'^(.*)_\d+.jpg$', item_tfms=Resize(224))

# %%
learn = vision_learner(dls, resnet34, metrics=error_rate)
learn.model.cpu()  # Just to be extra safe
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (1): Sequential(
#     (0): AdaptiveConcatPool2d(
#       (ap): AdaptiveAvgPool2d(output_size=1)
#       (mp): AdaptiveMaxPool2d(output_size=1)
#     )
#     (1): fastai.layers.Flatten(full=False)
#     (2): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=1024, out_features=512, bias=False)
#     (5): ReLU(inplace=True)
#     (6): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.5, inplace=False)
#     (8): Linear(in_features=512, out_features=37, bias=False)
#   )
# )

# %%
learn.fine_tune(1)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.458362</td>
#       <td>0.362025</td>
#       <td>0.109608</td>
#       <td>00:41</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.453610</td>
#       <td>0.259984</td>
#       <td>0.087280</td>
#       <td>00:53</td>
#     </tr>
#   </tbody>
# </table>

# %%
img = PILImage.create('dog.jpg')
img.show()

pred_class, pred_idx, outputs = learn.predict(img)
print(f"Prediction: {pred_class}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Prediction: great_pyrenees

# %%
learn.export('pets_classifier.pkl')

# %%
from fastai.vision.all import *

learn = load_learner('pets_classifier.pkl')
# Out:
# /Users/Stephane/Library/Python/3.9/lib/python/site-packages/fastai/learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[53], line 3
#       1 from fastai.vision.all import *
# ----> 3 learn = load_learner('pets_classifier.pkl')
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/learner.py:457, in load_learner(fname, cpu, pickle_module)
#     455     warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
#     456     load_kwargs = {"weights_only": False} if ismin_torch("2.6") else {}
# --> 457     res = torch.load(fname, map_location=map_loc, pickle_module=pickle_module, **load_kwargs)
#     458 except AttributeError as e:
#     459     e.args = [f"Custom classes or functions exported with your `Learner` not available in namespace. Re-declare/import before loading:\n\t{e.args[0]}"]
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/serialization.py:1425, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1422 if "encoding" not in pickle_load_args.keys():
#    1423     pickle_load_args["encoding"] = "utf-8"
# -> 1425 with _open_file_like(f, "rb") as opened_file:
#    1426     if _is_zipfile(opened_file):
#    1427         # The zipfile reader is going to advance the current file position.
#    1428         # If we want to actually tail call to torch.jit.load, we need to
#    1429         # reset back to the original position.
#    1430         orig_position = opened_file.tell()
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/serialization.py:751, in _open_file_like(name_or_buffer, mode)
#     749 def _open_file_like(name_or_buffer, mode):
#     750     if _is_path(name_or_buffer):
# --> 751         return _open_file(name_or_buffer, mode)
#     752     else:
#     753         if "w" in mode:
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/serialization.py:732, in _open_file.__init__(self, name, mode)
#     731 def __init__(self, name, mode):
# --> 732     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pets_classifier.pkl'

# %%
from fastai.vision.all import *

learn = load_learner('pets_classifier.pkl')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[54], line 3
#       1 from fastai.vision.all import *
# ----> 3 learn = load_learner('pets_classifier.pkl')
#
# File ~/Library/Python/3.9/lib/python/site-packages/fastai/learner.py:457, in load_learner(fname, cpu, pickle_module)
#     455     warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
#     456     load_kwargs = {"weights_only": False} if ismin_torch("2.6") else {}
# --> 457     res = torch.load(fname, map_location=map_loc, pickle_module=pickle_module, **load_kwargs)
#     458 except AttributeError as e:
#     459     e.args = [f"Custom classes or functions exported with your `Learner` not available in namespace. Re-declare/import before loading:\n\t{e.args[0]}"]
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/serialization.py:1425, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1422 if "encoding" not in pickle_load_args.keys():
#    1423     pickle_load_args["encoding"] = "utf-8"
# -> 1425 with _open_file_like(f, "rb") as opened_file:
#    1426     if _is_zipfile(opened_file):
#    1427         # The zipfile reader is going to advance the current file position.
#    1428         # If we want to actually tail call to torch.jit.load, we need to
#    1429         # reset back to the original position.
#    1430         orig_position = opened_file.tell()
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/serialization.py:751, in _open_file_like(name_or_buffer, mode)
#     749 def _open_file_like(name_or_buffer, mode):
#     750     if _is_path(name_or_buffer):
# --> 751         return _open_file(name_or_buffer, mode)
#     752     else:
#     753         if "w" in mode:
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/serialization.py:732, in _open_file.__init__(self, name, mode)
#     731 def __init__(self, name, mode):
# --> 732     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pets_classifier.pkl'

# %%
img = PILImage.create('newfoundland.jpg')
img.show()

pred_class, pred_idx, probs = learn.predict(img)
print(f"Prediction: {pred_class}, Confidence: {probs[pred_idx]:.4f}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Prediction: newfoundland, Confidence: 1.0000

# %%
learn.export('pets_classifier.pkl')
